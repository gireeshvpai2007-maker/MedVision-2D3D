# %% [markdown]
# # Experiment 01 — Dataset Exploration
#
# ## Objective
#
# Inspect and understand the dataset available for four-camera knee landmark detection.
#
# ## Questions
#
# - What camera views are available?
# - What is the image/video resolution?
# - What is the frame rate?
# - How many subjects are available?
# - Are the camera views synchronized?
# - Are the left and right knees represented?
# - Are the 20 landmarks already annotated?
# - What annotation format is provided?
# - Which landmarks are visible in each camera view?
#
# ## Current Status
#
# Dataset inspection will begin after the project dataset is received.
#
# No model training is performed in this notebook.
